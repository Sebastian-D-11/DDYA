# %% [markdown]
# ## Problema - Organización y búsqueda de productos en una tienda
#
# **Instrucción:** completa esta plantilla con tu diseño y desarrollo. Evita incluir soluciones generadas automáticamente.

# %%
# @title Ingrese datos
nombre_estudiante = "Gabriel Andrés Tautiva Amado" # @param {"type":"string"}
carnet = 1014659008 # @param {"type":"integer"}

# %% [markdown]
# ## 1) Descripción del problema **[1 pts]**
#
# Ejercicio: Organización y búsqueda de productos en una tienda
# Una tienda maneja una lista con los códigos numéricos de sus productos. Como los productos se registran a medida que llegan, los códigos inicialmente se encuentran desordenados.
#
# El encargado necesita desarrollar un programa que permita:
#
# 1. Registrar una cantidad n de productos.
# 2. Ordenar sus códigos utilizando Merge Sort.
# 3. Buscar un código específico utilizando Búsqueda Binaria.

# %% [markdown]
# ## 2) Requerimientos **[2 pts]**
#
# Requerimientos **Funcionales**:
#
# **RQF1**:  Solicitar y validar la cantidad de productos.
#
# **RQF2** : Almacenar la cantidad de productos.
#
# **RQF3**: Solicitar y validar el codigo de cada producto.
#
# **RQF4**:  Mediante el uso de Merge Sort, realizar la permutacion, es decir, orden ascendente.
#
# **RQF5**:  Solicitar y validar el codigo que desea buscar el usuario.
#
# **RQF6** : Realizar la busqueda del producto por medio de Busqueda Binaria e imprimir salida exitosa o de error dependiendo del caso.
#
# **RQF7**: Permitir al usuario multiples busquedas de codigos de productos
#
#
# Rquerimientos **No Funcionales**
#
# **RQNF1**:  Eficiencia: El programa debe ser lo mas eficiente posible para reducir costos temporales y monetarios, es decir, que sea optimizado. El programa cumple este objetivo al utilizar Merge Sort y la Busqueda Binaria. El programa se ve "afectado" y se traduce en
#
# $$\mathbf{T(n) = \Theta(n^2)} $$
#
# exclusivamente por la validacion de las entradas al buscar codigos duplicados
#
# **RQNF2** : Validacion: El programa constantemente realiza verificaciones en las entradas digitadas por el usuario
#
# **RQNF3**:  Mantenibilidad: La modularidad permite la modificacion sencilla del codigo en caso de ser necesario modificar datos, reutilizar funciones o cambiar ciertas partes de estas
#
# **RQNF4**:  Programacion: Se escogio el lenguaje de programacion Python ya que este lenguaje de alto nivel es comprensible y flexible, lo que nos facilitó la realización del codigo.

# %% [markdown]
# ## 3) Historias de usuario **[2 pts]**
#
# **HU1**: Digitación de la cantidad de productos (RQF1 y RQF2)
#
# Salida inicial: "Por favor digite la cantidad de productos que desea ordenar"
#
# Caso de aceptacion: Un número entero mayor o igual a 1
#
# Caso de error: Número menor a 1 o caracteres no numéricos
#
# Salida de error:  Dato inválido, digite nuevamente
#
#
# **HU2**: Registrar los productos y su respectivo codigo (RQF3)
#
# Salida inicial: “Digite el codigo del producto, n”
#
# Caso de aceptacion: El usuario ingresa un codigo valido
#
# Caso de error: El usuario ingresa un codigo ya registrado o valores no numericos
#
# salida de error: "El codigo es inválido, por favor digite numeros
#
# Salida de error: “El codigo es invalido, por favor digite nuevamente”
#
# Salida de exito:  “Productos registrados”
#
#
# **HU 3**: Busqueda del codigo. (RQF5-RQF6-RQF7)
#
# Salida inicial: “Por favor digite el codigo del producto que desea buscar”
#
# Caso de aceptacion:  Una serie de numeros que equivalen a un codigo
#
# Caso de error: El usuario digita valores no numericos .
#
# Caso de error 2:  El codigo no se encuentra registrado
#
# Salida de exito:  “El codigo si se encuentra registrado”
#
# Salida de error: “El codigo no es valido”
#
# Salida de error 2: “El codigo no se encuentra registrado”

# %% [markdown]
# ## 4) Diagramas de flujo **[5 pts]**
#
# ![image.png](attachment:image.png)
#
#
# En este diagrama de flujo se entiende la logica del programa. A grandes rasgos, lo que hace el programa es solicitar una cantidad de productos, despues de haber verificado, se procede al registro del codigo de cada producto. Posteriormente, los productos se organizan y despues se le solicita el codigo que desea buscar el usuario, una vez se tenga este dato, el programa busca el codigo, y si lo encuentra, notifica que el codigo si se encuentra registrado, en caso de no encontrarse, se notifica que el codigo no esta en la lista

# %% [markdown]
# ## 5) Diagramas de secuencia **[5 pts]**
#
# ![image-2.png](attachment:image-2.png)
#
#
# muestra el orden en que interactúan el encargado, el sistema y la lista de códigos, desde el registro y validación de los datos, pasando por el ordenamiento con Merge Sort, hasta la búsqueda con Búsqueda Binaria.

# %% [markdown]
# ## 6) Diagramas de casos de uso **[5 pts]**
#
# ![image-2.png](attachment:image-2.png)
#
# muestra las acciones que el encargado puede realizar en el sistema: registrar productos, ordenar códigos con Merge Sort y buscar un código con Búsqueda Binaria, junto con sus validaciones asociadas.

# %% [markdown]
# ## 7) Análisis de complejidad **[15 pts]**
# Incluye:
# - Justificación
# - Función T[n]
# - Mejor y peor caso con gráfica
#
#
# Para calcular la complejidad, se usara el Teorema maestro el cual se propone de la siguiente forma:
#
# ![image.png](attachment:image.png)
#
# Con los siguientes casos:
#
# ![image-2.png](attachment:image-2.png)
#
# Por lo que:
#
#
# Para el **Merge Sort**:
#
# ![image-10.png](attachment:image-10.png)
#
# ![image-5.png](attachment:image-5.png)
#
# El mejor caso es el azul, el naranja es el peor
#
# Para **Merge** (no tiene recursividad, por lo que no aplica el teorema maestro)
#
# ![image-6.png](attachment:image-6.png)
#
# ![image-7.png](attachment:image-7.png)
#
# El mejor caso es el azul, el naranja es el peor
#
#
# Para la **Busqueda Binaria**:
#
# ![image-4.png](attachment:image-4.png)
#
# ![image-8.png](attachment:image-8.png)
#
# El mejor caso es el azul, el naranja es el peor
#
# y para todo nuestro codigo:
#
# ![image-4.png](attachment:image-4.png)
#
# lo que da como costo total del codigo:
#
# $$T(n) = \Theta(n^2) + \Theta(n \log n) + \Theta(\log n) + \Theta(n) +\Theta(1)$$
#
# es decir : $$\mathbf{T(n) = \Theta(n^2)} $$
#
# ![image-9.png](attachment:image-9.png)

# %% [markdown]
# ## 8) Código funcional **[15 pts]**
# Incluye tu implementación completa.
#
# No pegues código incompleto; debe ser ejecutable.

# %%
def merge_sort(lista, p, r):
    if p < r:
        q = (p + r) // 2
        merge_sort(lista, p, q)
        merge_sort(lista, q + 1, r)
        merge(lista, p, q, r)

def merge(lista, p, q, r):
    izq = lista[p : q + 1]
    der = lista[q + 1 : r + 1]
    
    i = 0
    j = 0
    k = p

    while i < len(izq) and j < len(der):
        if izq[i] <= der[j]:
            lista[k] = izq[i]
            i = i + 1
        else:
            lista[k] = der[j]
            j = j + 1
        k = k + 1

    while i < len(izq):
        lista[k] = izq[i]
        i = i + 1
        k = k + 1

    while j < len(der):
        lista[k] = der[j]
        j = j + 1
        k = k + 1


def busqueda_binaria(arreglo, dato):
    izq = 0
    der = len(arreglo) - 1

    while izq <= der:
        medio = (izq + der) // 2
        if arreglo[medio] == dato:
            return True
        elif arreglo[medio] < dato:
            izq = medio + 1
        else:
            der = medio - 1
    return False

def main():
    productos = []
    
    print("REGISTRO DE PRODUCTOS")
    cant = input("Ingrese la cantidad de productos a registrar: ")
    
    while not cant.isdigit() or int(cant) < 1:
        print("Error: Ingrese un numero valido mayor a 0.")
        cant = input("Ingrese la cantidad de productos a registrar: ")
        
    cant = int(cant)

    for i in range(cant):
        repetido = True
        
        while repetido:
            cod = input("Codigo del producto #" + str(i + 1) + ": ")
            
            if not cod.isdigit():
                print("Error: Solo se permiten digitos.")
            else:
                num = int(cod)

                if num in productos:
                    print("El codigo", num, "ya fue ingresado, intente de nuevo.")
                else:
                    productos.append(num)
                    repetido = False

    print("\nCodigos ingresados:", productos)

    merge_sort(productos, 0, len(productos) - 1)
    print("Codigos ordenados:", productos)

    print("\n--- BUSQUEDA ---")
    band = True

    while band:
        buscado = input("Codigo que desea buscar")

        while not buscado.isdigit():
            print("Error,Ingrese solo numeros")
            buscado = input("Codigo que desea buscar: ")

        buscado = int(buscado)

        
        if busqueda_binaria(productos, buscado):
            print("El producto", buscado, "SI existe en el registro.")
        else:
            print("El producto", buscado, "NO fue encontrado.")

        print("desea buscar otro codigo?, escribir unicamente SI o NO")
        x = input()
        while x != "SI" and x!= "NO":
            print("repuesta invalida, intente nuevamente")
            x = input()

        if x == "NO":
            band = False

    print("Gracias por usar el programa")

main()
# Out:
# -BIENVENIDO AL REGISTRO DE PRODUCTOS-
# Preguntaremos por una cantidad de productos deseados para ingresar, despues debera escribir el codigo de cada producto, de esta forma sera guardado y podra realizar la busqueda del producto que necesite.
